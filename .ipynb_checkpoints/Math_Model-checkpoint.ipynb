# %% [markdown]
# <h1>CAPSTONE PROJECT - JOSHUA OLUWATOBILOBA ISEYEMI</h1>

# %% [markdown]
# <h2 style="color: red;">Introduction</h2>
#     My name is Iseyemi Joshua Oluwatobiloba(surname firstname middlename) and this is my AI/ML CAPSTONE PROJECT
#     This project is used to text my knowledge on all that I have done so far on my AI/ML class and test my
#     abilities to create an AI tool from scratch to deployment.<br><br>
# <div id='info'>
#     Name(firstname lastname middlename): Joshua Oluwatobiloba Iseyemi<br>
#     Class: AI/ML Class<br>
#     Squad: Squad 3<br>
#     Program: Digital Skillup Africa<br>
#     Program_Coordinators: The Incubator Hub<br>
#     Instuctors: Mr. Oluwole Olajide, Mr. Blessing Olorunfemi, Mr. Isaac Oyekunle<br>
#     Project: Design and Deployment of an AI-Powered Predictive System<br><hr>
#     <b>Contact Info</b><br>
#     <span>
#         Whatsapp:<br>
#             <a href="https://wa.link/d8nye1" style="text-decoration: none">Primary</a><br>
#             <a href="https://wa.link/lpmy83">Secondary</a>
#     </span><br>
#     <span>
#         E-mail:<br>
#             iseyemijoshua002@gmail.com
#     </span><br>
#     <span>
#         Socials:<br>
#             <a href='https://www.kaggle.com/joshuaiseyemi'>Kaggle</a><br>
#             <a href='https://github.com/espejo002'>GitHub</a>
#     </span>
# </div>

# %% [markdown]
# <h2 style='color: red;'>Project Overview</h2>
#     This project uses data fron UCI machine learning repository. It focuses on students in two schools in Portugal providing theier performance on Mathematics and Portuguese Language and also talks about their social lives outside the school.<br>
#     The aim of this model is to predice whether a student will pass the subjects given some specific features.<br>
#     I will primarily focus on the math dataset for this project.<br>
#     To download the dataset_math, <a href='https://archive.ics.uci.edu/static/public/320/student+performance.zip'>Click Here</a>.
#     For more information, <a href='https://archive.ics.uci.edu/dataset_math/320/student+performance'>Visit Here</a>
#
# <style>
#     a {
#         text-decoration: none;
#     }
# </style>

# %% [markdown]
# <h2 style='color: darkblue'>Model</h2>

# %% [markdown]
# ### Install and Import Required Modules

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn plotly

# %% [markdown]
# ### Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.preprocessing as sk
import plotly.express as px

from sklearn.metrics import confusion_matrix, mean_squared_error, mean_absolute_error, r2_score, roc_curve, auc

print('All imports were successful!')
# Out:
# All imports were successful!

# %% [markdown]
# ### Load the dataset

# %%
dataset_math = pd.read_csv("student-mat.csv",sep=";")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

print('Dataset was loaded successfully!')
# Out:
# Dataset was loaded successfully!

# %% [markdown]
# ### Performing Statistical Analysis

# %%
dataset_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
dataset_math.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 390  course    other           1          2         2        no    yes  yes
# 391  course   mother           2          1         0        no     no   no
# 392  course    other           1          1         3        no     no   no
# 393  course   mother           3          1         0        no     no   no
# 394  course   father           1          1         0        no     no   no
#
# ...

# %%
dataset_math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
dataset_math.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  reason guardian  traveltime   studytime  \
# count   395.000000    395    395     395      395  395.000000  395.000000
# ...

# %%
(dataset_math == 'yes').sum()
# Out:
# school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            0
# Fjob            0
# reason          0
# guardian        0
# traveltime      0
# studytime       0
# failures        0
# schoolsup      51
# famsup        242
# paid          181
# activities    201
# nursery       314
# higher        375
# internet      329
# romantic      132
# famrel          0
# freetime        0
# goout           0
# Dalc            0
# Walc            0
# health          0
# absences        0
# G1              0
# G2              0
# G3              0
# dtype: int64

# %%
dataset_math.shape
# Out:
# (395, 33)

# %%
# Defining target column
target = 'G3'

# To verify if it was created
print(target)
# Out:
# G3

# %%
# Defining only the numerical columns
df = dataset_math.select_dtypes(include='int64')
df.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %%
# Plotting histograms
df.hist(figsize=(15, 10), bins=10, color='red', edgecolor='blue')
plt.suptitle('Feature Distributions', fontsize=20)
plt.tight_layout()
plt.show()

# %%
# Making Boxplots
plt.figure(figsize =(20, 20))
for idx, col in enumerate(df):
    plt.subplot(4, 4, idx+1)
    sns.boxplot(x = f'{target}', y = col, data = df, palette = 'viridis')
    plt.title(f'{col} vs {target}')
    plt.xlabel(target)
    plt.ylabel(col)
    plt.grid(axis='y', linestyle='--', alpha = 0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\iseye\AppData\Local\Temp\ipykernel_6128\427600121.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = f'{target}', y = col, data = df, palette = 'viridis')
# C:\Users\iseye\AppData\Local\Temp\ipykernel_6128\427600121.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = f'{target}', y = col, data = df, palette = 'viridis')
# C:\Users\iseye\AppData\Local\Temp\ipykernel_6128\427600121.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = f'{target}', y = col, data = df, palette = 'viridis')
# ...

# %%
# Making the correlation heatmap

plt.figure(figsize=(25, 25))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Matrix', fontsize=50)
plt.show()

# %%
# Identifying columns whose correlations do not meet the threshold

X = df.drop(target, axis=1)
y = df[target]

df_for_corr_analysis = pd.concat([X, y], axis=1)

feature_target_correlations = df_for_corr_analysis.corr().abs()[target].drop(target)
print(f'\nAbsolute Correlation of each feature with {target}:\n', feature_target_correlations)

correlation_threshold = 0.07

invalid_cols = feature_target_correlations[
    feature_target_correlations < correlation_threshold
].index.to_list()
print(f'\n\nLow Correlating Columns below {correlation_threshold}:\n{invalid_cols}')

number_of_remaining_cols = df.columns.size - len(invalid_cols) - 1
print(f'\n\nNumber of features remaining: {number_of_remaining_cols}')
# Out:
# Absolute Correlation of each feature with G3:
#  age           0.161579
# Medu          0.217147
# Fedu          0.152457
# traveltime    0.117142
# studytime     0.097820
# failures      0.360415
# famrel        0.051363
# freetime      0.011307
# goout         0.132791
# Dalc          0.054660
# Walc          0.051939
# health        0.061335
# absences      0.034247
# G1            0.801468
# G2            0.904868
# Name: G3, dtype: float64
#
#
# Low Correlating Columns below 0.07:
# ['famrel', 'freetime', 'Dalc', 'Walc', 'health', 'absences']
#
#
# Number of features remaining: 9

# %%
# Removing the low correlating columns
df = df.drop(invalid_cols, axis=1)
df.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  goout  G1  G2  G3
# 0   18     4     4           2          2         0      4   5   6   6
# 1   17     1     1           1          2         0      3   5   5   6
# 2   15     1     1           1          2         3      2   7   8  10
# 3   15     4     2           1          3         0      2  15  14  15
# 4   16     3     3           1          2         0      2   6  10  10

# %% [markdown]
# ### Scaling

# %%
# MinAbs Scaling
from sklearn.preprocessing import MinMaxScaler

X = df.drop(target, axis=1)
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

print('Dataset was scaled successfully')
# Out:
# Dataset was scaled successfully

# %% [markdown]
# ### Splitting the Dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3, random_state=42)

print(f'Training Dataset Size: {X_train.shape}')
print(f'Testing Dataset Size: {X_test.shape}')
print(f'Target Training Size: {y_train.shape}')
print(f'Target Testing Size: {y_test.shape}')
# Out:
# Training Dataset Size: (276, 9)
# Testing Dataset Size: (119, 9)
# Target Training Size: (276,)
# Target Testing Size: (119,)

# %% [markdown]
# ### Training the Model and Performing Evaluations

# %% [markdown]
# <pre>
#     Since the features correspond linearly to the label, a linear regression
#     model will be suitable for this project
# </pre>

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print('______________ LINEAR REGRESSION MODEL ______________')

y_pred = model.predict(X_test)

# Model Evaluation
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) # Root Mean Squared Error
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred) # R-squared (Coefficient of Determination)

print("\n--- Regression Model Evaluation ---")
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'R-squared (R2): {r2:.4f}')
# Out:
# ______________ LINEAR REGRESSION MODEL ______________
#
# --- Regression Model Evaluation ---
# Mean Squared Error (MSE): 4.5117
# Root Mean Squared Error (RMSE): 2.1241
# Mean Absolute Error (MAE): 1.3036
# R-squared (R2): 0.7948

# %% [markdown]
# ### Model File Generation

# %% [markdown]
# <pre>
#     After the successful evaluation of or model, we can now export is as a .pkl file or
#     a .joblib file for deployment
# </pre>

# %%
import joblib

model_file_name = "math_model.pkl"
joblib.dump((scaler, model), model_file_name)
print(f'Model file {model_file_name} was successfully generated!')
# Out:
# Model file math_model.pkl was successfully generated!
